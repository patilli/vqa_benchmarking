# %%
import torch
from datasets.VQADataset import VQADataSample, VQADataset, get_feat_extractor
from models.ban.model import BANAdapter

# %%
ds = VQADataset(question_file='./.data/questions.json', annotation_file='./.data/anns.json', img_dir='/home/users2/vaethdk/vqa_data/datasets/OK-VQA/images/val2014', img_feat_dir='/home/users2/vaethdk/vqa_data/datasets/OK-VQA/images/features')
# Out:
# ...
# 100%|██████████| 214354/214354 [00:00<00:00, 1503799.10it/s]

# %%
vocab = ds.q_vocab

# %%
ban = BANAdapter(device="cuda:2", vocab=vocab, ckpt_file='ban8.pt')

# %%
os.environ['CUDA_VISIBLE_DEVICES'] = "2"

# %%
get_feat_extractor()
# Out:
# size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (5): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv2): Conv2d(
#           256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#           (norm): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (conv3): Conv2d(
#           256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#           (norm): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (6): BottleneckBlock(
#         (conv1): Conv2d(
#           1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
# ...

# %% [markdown]
# Image
# <img src="/home/users2/vaethdk/vqa_data/datasets/OK-VQA/images/val2014/COCO_val2014_000000262148.jpg"/>

# %%
ds[0]._image_path
# Out:
# '/home/users2/vaethdk/vqa_data/datasets/OK-VQA/images/val2014/COCO_val2014_000000262148.jpg'

# %%
ds[0].image_features
# Out:
# tensor([[0.0000e+00, 2.1084e-01, 1.0112e-02,  ..., 5.5538e-01, 1.7009e-02,
#          1.4562e+00],
#         [0.0000e+00, 6.2113e-02, 4.5111e-03,  ..., 3.5800e-02, 0.0000e+00,
#          1.7751e+00],
#         [7.2868e-02, 0.0000e+00, 3.6447e-03,  ..., 0.0000e+00, 5.3549e-02,
#          0.0000e+00],
#         ...,
#         [8.8706e-02, 6.6681e-01, 8.2265e-02,  ..., 0.0000e+00, 4.0624e+00,
#          3.9128e-02],
#         [1.4420e-01, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 1.6571e-02,
#          3.5150e-02],
#         [1.3502e+00, 1.9150e+00, 1.3539e-03,  ..., 3.7506e-02, 4.2401e+00,
#          5.0776e-01]])

# %%
# !nvidia-smi
# Out:
# Thu Jun 17 21:55:21 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.24.02    Driver Version: 465.24.02    CUDA Version: 11.3     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  On   | 00000000:01:00.0 Off |                  N/A |
# | 30%   38C    P2   154W / 350W |   3608MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
result = ban.forward([ds[0]])

# %%
result.argmax(dim=-1)
# Out:
# tensor([134], device='cuda:2')

# %%
ds[1]._q_tokens
# Out:
# ['what', 'are', 'the', 'people', 'in', 'the', 'background', 'doing']

# %%
ds[1].question_tokenized
# Out:
# ['what', 'are', 'the', 'people', 'in', 'the', 'background', 'doing']

# %%
ds[1].question_features

# %%
print(ds[1]._q_feats)
# Out:
# None

# %%
ds[1].image_features
# Out:
# tensor([[0.0000e+00, 2.1084e-01, 1.0112e-02,  ..., 5.5538e-01, 1.7009e-02,
#          1.4562e+00],
#         [0.0000e+00, 6.2113e-02, 4.5111e-03,  ..., 3.5800e-02, 0.0000e+00,
#          1.7751e+00],
#         [7.2868e-02, 0.0000e+00, 3.6447e-03,  ..., 0.0000e+00, 5.3549e-02,
#          0.0000e+00],
#         ...,
#         [8.8706e-02, 6.6681e-01, 8.2265e-02,  ..., 0.0000e+00, 4.0624e+00,
#          3.9128e-02],
#         [1.4420e-01, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 1.6571e-02,
#          3.5150e-02],
#         [1.3502e+00, 1.9150e+00, 1.3539e-03,  ..., 3.7506e-02, 4.2401e+00,
#          5.0776e-01]])

# %%
from metrics.metrics import calculate_metrics
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-17-d32df3b631e0> in <module>
# ----> 1 from metrics.metrics import calculate_metrics
#
# /mount/arbeitsdaten41/projekte/asr-2/vaethdk/imgfeats_detectron/bottom-up-attention.pytorch/metrics/metrics.py in <module>
#       8
#       9 from datasets.dataset import DatasetModelAdapter, DiagnosticDataset, DataSample
# ---> 10 from metrics.bias import eval_bias, inputs_for_image_bias_featurespace, inputs_for_image_bias_wordspace, inputs_for_question_bias_featurespace, inputs_for_question_bias_imagespace
#      11 from metrics.robustness import eval_robustness, inputs_for_image_robustness_featurespace, inputs_for_image_robustness_imagespace, inputs_for_question_robustness_featurespace, inputs_for_question_robustness_wordspace
#      12 from metrics.sear import eval_sears, inputs_for_question_sears
#
# ...

# %%
calculate_metrics()
