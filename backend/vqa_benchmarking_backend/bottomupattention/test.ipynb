# %%
import numpy as np

# %%
f = np.load('./output/000456.npz', allow_pickle=True)

# %%
list(f.keys())
# Out:
# ['x', 'bbox', 'num_bbox', 'image_h', 'image_w', 'info']

# %%
f['info']
# Out:
# array({'image_id': '000456', 'image_h': 375, 'image_w': 500, 'num_boxes': 43, 'objects_id': array([ 299,  299,  299,  381,  833,  937,  287,  758,  594,  493,  128,
#         299,  500,  969,  287,  222,  937,  758,  299,  299, 1154,  453,
#         292,  937,  289,  601,  978,  299,  299,  222,  833,  128,  493,
#         314,  453,  453,  576,   55,  978,  991,  453,  292,  715]), 'objects_conf': array([0.60502666, 0.45114863, 0.50608605, 0.6486198 , 0.5593259 ,
#        0.51891774, 0.7897017 , 0.23869841, 0.38032526, 0.7660093 ,
#        0.31233954, 0.45499083, 0.55423105, 0.3862791 , 0.28131998,
#        0.8073057 , 0.6232253 , 0.27778235, 0.28021768, 0.30031055,
#        0.28523883, 0.4451816 , 0.2646984 , 0.70807314, 0.5669319 ,
#        0.21396895, 0.32758543, 0.36403942, 0.2694074 , 0.42143157,
#        0.49200848, 0.25333703, 0.34546703, 0.49818066, 0.3458407 ,
#        0.5800392 , 0.32477903, 0.9480065 , 0.5247614 , 0.21962239,
# ...

# %%
f['x'].shape
# Out:
# (43, 2048)

# %%
f['num_bbox']
# Out:
# array(43)

# %%
f['bbox']
# Out:
# array([[2.82237625e+01, 1.08990753e+02, 4.82464783e+02, 3.40424103e+02],
#        [1.85311157e+02, 5.37587357e+01, 4.99375000e+02, 3.74375000e+02],
#        [0.00000000e+00, 1.05694199e+02, 3.14282745e+02, 3.74375000e+02],
#        [3.69703979e+02, 0.00000000e+00, 4.85742950e+02, 5.26379356e+01],
#        [1.31737411e+02, 1.24949165e+02, 1.76278717e+02, 1.63544952e+02],
#        [2.88077209e+02, 1.65192139e+02, 4.99375000e+02, 3.74375000e+02],
#        [9.32903976e+01, 6.63875504e+01, 2.54486191e+02, 2.13522446e+02],
#        [9.63284760e+01, 2.35022125e+02, 1.19257423e+02, 2.54363434e+02],
#        [4.40697670e-01, 3.95712242e+01, 1.10280228e+02, 1.19955116e+02],
#        [1.03582771e+02, 2.25439255e+02, 2.60102081e+02, 2.74587921e+02],
#        [1.06819923e+02, 1.66041565e+02, 1.55189590e+02, 2.03248245e+02],
#        [0.00000000e+00, 1.10749283e+02, 1.00305359e+02, 3.61021027e+02],
#        [9.36774216e+01, 3.40668640e+01, 4.33432373e+02, 1.13608665e+02],
# ...
